# %% [markdown]
# Sales Price Prediction Using Python
#
# By - Natasha Banerji For Data Science Internship At OASIS INFOBYTE, INDIA.
#
#
#
# We will first import the necessary libraries and the dataset for the implementation of the task.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

data = pd.read_csv(r"C:\Users\NATASHA BANERJI\Desktop\ADVERTISE CSV\Advertising.csv")

# %% [markdown]
# Then, in order to view the first 5 rows of the dataset, we use the head() function.

# %%
print(data.head())
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# Then, we need to check if the dataset contains any null values in it or not using isnull() function.

# %%
print(data.isnull().sum())
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# Now we will take a look at the correlation between features before we start training the machine learning model to predict future sales, using a heatmap.

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12, 10))
sns.heatmap(data.corr())
plt.show()

# %% [markdown]
# Now we will prepare the data to fit into the machine learning model and then I will use the Linear Regression Algorithm to train a sales prediction model using Python.

# %%
x = np.array(data.drop(labels=["Sales"], axis=1))
y = np.array(data["Sales"])
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

data = pd.DataFrame(data={"Predicted Sales": ypred.flatten()})
print(data)
# Out:
#     Predicted Sales
# 0         16.412277
# 1         20.843193
# 2         21.511869
# 3         10.653100
# 4         22.124058
# 5         13.123835
# 6         21.037489
# 7          7.503854
# 8         13.647870
# 9         15.120409
# 10         9.020556
# 11         6.706666
# 12        14.401551
# 13         8.886090
# 14         9.743533
# 15        12.215520
# 16         8.713709
# 17        16.294145
# 18        10.268023
# 19        18.804982
# 20        19.588647
# 21        13.223183
# 22        12.364787
# 23        21.314736
# 24         7.797347
# 25         5.781900
# 26        20.749348
# 27        11.954767
# 28         9.199109
# 29         8.521787
# 30        12.404313
# 31         9.948652
# 32        21.368803
# 33        12.253748
# 34        18.299435
# 35        20.133474
# 36        14.074646
# 37        20.885947
# 38        11.052150
# 39         4.551687

# %% [markdown]
# So this is how we can predict future sales of a product with machine learning, using Linear Regression.
